# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11263485266","type":"PullRequestReviewCommentEvent","actor":{"id":4710635,"login":"ellatrix","display_login":"ellatrix","gravatar_id":"","url":"https://api.github.com/users/ellatrix","avatar_url":"https://avatars.githubusercontent.com/u/4710635?"},"repo":{"id":80862584,"name":"WordPress/gutenberg","url":"https://api.github.com/repos/WordPress/gutenberg"},"payload":{"action":"created","comment":{"url":"https://api.github.com/repos/WordPress/gutenberg/pulls/comments/365898985","pull_request_review_id":341970300,"id":365898985,"node_id":"MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDM2NTg5ODk4NQ==","diff_hunk":"@@ -273,14 +274,27 @@ const Popover = ( {\\n \\t\\t\\t\\tcontentRect.current = contentRef.current.getBoundingClientRect();\\n \\t\\t\\t}\\n \\n+\\t\\t\\tlet boundaryElement;\\n+\\n+\\t\\t\\tif ( __unstableBoundaryParent ) {\\n+\\t\\t\\t\\tboundaryElement = containerRef.current.closest( \'.popover-slot\' ).parentNode;","path":"packages/components/src/popover/index.js","position":15,"original_position":15,"commit_id":"9812fe60472047b494719d1b8127c319bf8722df","original_commit_id":"9812fe60472047b494719d1b8127c319bf8722df","user":{"login":"ellatrix","id":4710635,"node_id":"MDQ6VXNlcjQ3MTA2MzU=","avatar_url":"https://avatars3.githubusercontent.com/u/4710635?v=4","gravatar_id":"","url":"https://api.github.com/users/ellatrix","html_url":"https://github.com/ellatrix","followers_url":"https://api.github.com/users/ellatrix/followers","following_url":"https://api.github.com/users/ellatrix/following{/other_user}","gists_url":"https://api.github.com/users/ellatrix/gists{/gist_id}","starred_url":"https://api.github.com/users/ellatrix/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/ellatrix/subscriptions","organizations_url":"https://api.github.com/users/ellatrix/orgs","repos_url":"https://api.github.com/users/ellatrix/repos","events_url":"https://api.github.com/users/ellatrix/events{/privacy}","received_events_url":"https://api.github.com/users/ellatrix/received_events","type":"User","site_admin":false},"body":"Store the ref in context?","created_at":"2020-01-13T16:28:17Z","updated_at":"2020-01-13T16:28:18Z","html_url":"https://github.com/WordPress/gutenberg/pull/19322#discussion_r365898985","pull_request_url":"https://api.github.com/repos/WordPress/gutenberg/pulls/19322","author_association":"MEMBER","_links":{"self":{"href":"https://api.github.com/repos/WordPress/gutenberg/pulls/comments/365898985"},"html":{"href":"https://github.com/WordPress/gutenberg/pull/19322#discussion_r365898985"},"pull_request":{"href":"https://api.github.com/repos/WordPress/gutenberg/pulls/19322"}},"in_reply_to_id":365896440},"pull_request":{"url":"https://api.github.com/repos/WordPress/gutenberg/pulls/19322","id":356628381,"node_id":"MDExOlB1bGxSZXF1ZXN0MzU2NjI4Mzgx","html_url":"https://github.com/WordPress/gutenberg/pull/19322","diff_url":"https://github.com/WordPress/gutenberg/pull/19322.diff","patch_url":"https://github.com/WordPress/gutenberg/pull/19322.patch","issue_url":"https://api.github.com/repos/WordPress/gutenberg/issues/19322","number":19322,"state":"open","locked":false,"title":"Block Popover: editor canvas as boundary","user":{"login":"ellatrix","id":4710635,"node_id":"MDQ6VXNlcjQ3MTA2MzU=","avatar_url":"https://avatars3.githubusercontent.com/u/4710635?v=4","gravatar_id":"","url":"https://api.github.com/users/ellatrix","html_url":"https://github.com/ellatrix","followers_url":"https://api.github.com/users/ellatrix/followers","following_url":"https://api.github.com/users/ellatrix/following{/other_user}","gists_url":"https://api.github.com/users/ellatrix/gists{/gist_id}","starred_url":"https://api.github.com/users/ellatrix/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/ellatrix/subscriptions","organizations_url":"https://api.github.com/users/ellatrix/orgs","repos_url":"https://api.github.com/users/ellatrix/repos","events_url":"https://api.github.com/users/ellatrix/events{/privacy}","received_e ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11263485266',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 4710635,
#    'login': 'ellatrix',
#    'display_login': 'ellatrix',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ellatrix',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4710635?'},
#   'repo': {'id': 80862584,
#    'name': 'WordPress/gutenberg',
#    'url': 'https://api.github.com/repos/WordPress/gutenberg'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/WordPress/gutenberg/pulls/comments/365898985',
#     'pull_request_review_id': 341970300,
#     'id': 365898985,
#     'node_id': 'MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDM2NTg5ODk4NQ==',
#     'diff_hunk': "@@ -273,14 +274,27 @@ const Popover = ( {\n \t\t\t\tcontentRect.current = contentRef.current.getBoundingClientRect();\n \t\t\t}\n \n+\t\t\tlet boundaryElement;\n+\n+\t\t\tif ( __unstableBoundaryParent ) {\n+\t\t\t\tboundaryElement = containerRef.current.closest( '.popover-slot' ).parentNode;",
#     'path': 'packages/components/src/popover/index.js',
#     'position': 15,
#     'original_position': 15,
#     'commit_id': '9812fe60472047b494719d1b8127c319bf8722df',
#     'original_commit_id': '9812fe60472047b494719d1b8127c319bf8722df',
#     'user': {'login': 'ellatrix',
#      'id': 4710635,
#      'node_id': 'MDQ6VXNlcjQ3MTA2MzU=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/4710635?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ellatrix',
#      'html_url': 'https://github.com/ellatrix',
#      'followers_url': 'https://api.github.com/users/ellatrix/followers',
#      'following_url': 'https://api.github.com/users/ellatrix/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ellatrix/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ellatrix/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ellatrix/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ellatrix/orgs',
#      'repos_url': 'https://api.github.com/users/ellatrix/repos',
#      'events_url': 'https://api.github.com/users/ellatrix/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ellatrix/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Store the ref in context?',
#     'created_at': '2020-01-13T16:28:17Z',
#     'updated_at': '2020-01-13T16:28:18Z',
#     'html_url': 'https://github.com/WordPress/gutenberg/pull/19322#discussion_r365898985',
#     'pull_request_url': 'https://api.github.com/repos/WordPress/gutenberg/pulls/19322',
#     'author_association': 'MEMBER',
#     '_links': {'self': {'href': 'https://api.github.com/repos/WordPress/gutenberg/pulls/comments/365898985'},
#      'html': {'href': 'https://github.com/WordPress/gutenberg/pull/19322#discussion_r365898985'},
#      'pull_request': {'href': 'https://api.github.com/repos/WordPress/gutenberg/pulls/19322'}},
#     'in_reply_to_id': 365896440},
#    'pull_request': {'url': 'https://api.github.com/repos/WordPress/gutenberg/pulls/19322',
#     'id': 356628381,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzU2NjI4Mzgx',
#     'html_url': 'https://github.com/WordPress/gutenberg/pull/19322',
#     'diff_url': 'https://github.com/WordPress/gutenberg/pull/19322.diff',
#     'patch_url': 'https://github.com/WordPress/gutenberg/pull/19322.patch',
#     'issue_url': 'https://api.github.com/repos/WordPress/gutenberg/issues/19322',
#     'number': 19322,
#     'state': 'open',
#     'locked': False,
#     'title': 'Block Popover: editor canvas as boundary',
#     'user': {'login': 'ellatrix',
#      'id': 4710635,
#      'node_id': 'MDQ6VXNlcjQ3MTA2MzU=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/4710635?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ellatrix',
#      'html_url': 'https://github.com/ellatrix',
#      'followers_url': 'https://api.github.com/users/ellatrix/followers',
#      'following_url': 'https://api.github.com/users/ellatrix/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ellatrix/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ellatrix/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ellatrix/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ellatrix/orgs',
#      'repos_url': 'https://api.github.com/users/ellatrix/repos',
#      'events_url': 'https://api.github.com/users/ellatrix/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ellatrix/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '## Description\r\n\r\nThis is just a proof of concept. I wouldn\'t recommend using it on its own as it may look a bit strange with the currently block selection style and the movers on the side.\r\n\r\nEventually we should rewrite `Popover` (or use an external component), but I\'m trying to avoid that here so it unblocks other work being don.\r\n\r\n<img width="419" alt="Screenshot 2019-12-24 at 13 47 15" src="https://user-images.githubusercontent.com/4710635/71413924-bf7d7500-2654-11ea-83ee-04ac59c4af26.png">\r\n\r\n## How has this been tested?\r\n<!-- Please describe in detail how you tested your changes. -->\r\n<!-- Include details of your testing environment, tests ran to see how -->\r\n<!-- your change affects other areas of the code, etc. -->\r\n\r\n## Screenshots <!-- if applicable -->\r\n\r\n## Types of changes\r\n<!-- What types of changes does your code introduce?  -->\r\n<!-- Bug fix (non-breaking change which fixes an issue) -->\r\n<!-- New feature (non-breaking change which adds functionality) -->\r\n<!-- Breaking change (fix or feature that would cause existing functionality to not work as expected) -->\r\n\r\n## Checklist:\r\n- [ ] My code is tested.\r\n- [ ] My code follows the WordPress code style. <!-- Check code: `npm run lint`, Guidelines: https://make.wordpress.org/core/handbook/best-practices/coding-standards/javascript/ -->\r\n- [ ] My code follows the accessibility standards. <!-- Guidelines: https://make.wordpress.org/core/handbook/best-practices/coding-standards/accessibility-coding-standards/ -->\r\n- [ ] My code has proper inline documentation. <!-- Guidelines: https://make.wordpress.org/core/handbook/best-practices/inline-documentation-standards/javascript/ -->\r\n- [ ] I\'ve included developer documentation if appropriate. <!-- Handbook: https://developer.wordpress.org/block-editor/ -->\r\n- [ ] I\'ve updated all React Native files affected by any refactorings/renamings in this PR. <!-- React Native mobile Gutenberg guidelines: https://github.com/WordPress/gutenberg/blob/master/docs/contributors/native-mobile.md -->.\r\n',
#     'created_at': '2019-12-24T12:55:05Z',
#     'updated_at': '2020-01-13T16:28:18Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '4afb488c452e7e7770f76084e6949a3c9863c69f',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [{'login': 'daniloercoli',
#       'id': 518232,
#       'node_id': 'MDQ6VXNlcjUxODIzMg==',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/518232?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/daniloercoli',
#       'html_url': 'https://github.com/daniloercoli',
#       'followers_url': 'https://api.github.com/users/daniloercoli/followers',
#       'following_url': 'https://api.github.com/users/daniloercoli/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/daniloercoli/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/daniloercoli/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/daniloercoli/subscriptions',
#       'organizations_url': 'https://api.github.com/users/daniloercoli/orgs',
#       'repos_url': 'https://api.github.com/users/daniloercoli/repos',
#       'events_url': 'https://api.github.com/users/daniloercoli/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/daniloercoli/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'atimmer',
#       'id': 584693,
#       'node_id': 'MDQ6VXNlcjU4NDY5Mw==',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/584693?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/atimmer',
#       'html_url': 'https://github.com/atimmer',
#       'followers_url': 'https://api.github.com/users/atimmer/followers',
#       'following_url': 'https://api.github.com/users/atimmer/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/atimmer/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/atimmer/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/atimmer/subscriptions',
#       'organizations_url': 'https://api.github.com/users/atimmer/orgs',
#       'repos_url': 'https://api.github.com/users/atimmer/repos',
#       'events_url': 'https://api.github.com/users/atimmer/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/atimmer/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'noisysocks',
#       'id': 612155,
#       'node_id': 'MDQ6VXNlcjYxMjE1NQ==',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/612155?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/noisysocks',
#       'html_url': 'https://github.com/noisysocks',
#       'followers_url': 'https://api.github.com/users/noisysocks/followers',
#       'following_url': 'https://api.github.com/users/noisysocks/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/noisysocks/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/noisysocks/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/noisysocks/subscriptions',
#       'organizations_url': 'https://api.github.com/users/noisysocks/orgs',
#       'repos_url': 'https://api.github.com/users/noisysocks/repos',
#       'events_url': 'https://api.github.com/users/noisysocks/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/noisysocks/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'SergioEstevao',
#       'id': 651601,
#       'node_id': 'MDQ6VXNlcjY1MTYwMQ==',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/651601?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/SergioEstevao',
#       'html_url': 'https://github.com/SergioEstevao',
#       'followers_url': 'https://api.github.com/users/SergioEstevao/followers',
#       'following_url': 'https://api.github.com/users/SergioEstevao/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/SergioEstevao/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/SergioEstevao/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/SergioEstevao/subscriptions',
#       'organizations_url': 'https://api.github.com/users/SergioEstevao/orgs',
#       'repos_url': 'https://api.github.com/users/SergioEstevao/repos',
#       'events_url': 'https://api.github.com/users/SergioEstevao/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/SergioEstevao/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'talldan',
#       'id': 677833,
#       'node_id': 'MDQ6VXNlcjY3NzgzMw==',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/677833?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/talldan',
#       'html_url': 'https://github.com/talldan',
#       'followers_url': 'https://api.github.com/users/talldan/followers',
#       'following_url': 'https://api.github.com/users/talldan/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/talldan/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/talldan/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/talldan/subscriptions',
#       'organizations_url': 'https://api.github.com/users/talldan/orgs',
#       'repos_url': 'https://api.github.com/users/talldan/repos',
#       'events_url': 'https://api.github.com/users/talldan/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/talldan/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'Soean',
#       'id': 695201,
#       'node_id': 'MDQ6VXNlcjY5NTIwMQ==',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/695201?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Soean',
#       'html_url': 'https://github.com/Soean',
#       'followers_url': 'https://api.github.com/users/Soean/followers',
#       'following_url': 'https://api.github.com/users/Soean/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Soean/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Soean/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Soean/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Soean/orgs',
#       'repos_url': 'https://api.github.com/users/Soean/repos',
#       'events_url': 'https://api.github.com/users/Soean/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Soean/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'gziolo',
#       'id': 699132,
#       'node_id': 'MDQ6VXNlcjY5OTEzMg==',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/699132?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/gziolo',
#       'html_url': 'https://github.com/gziolo',
#       'followers_url': 'https://api.github.com/users/gziolo/followers',
#       'following_url': 'https://api.github.com/users/gziolo/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/gziolo/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/gziolo/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/gziolo/subscriptions',
#       'organizations_url': 'https://api.github.com/users/gziolo/orgs',
#       'repos_url': 'https://api.github.com/users/gziolo/repos',
#       'events_url': 'https://api.github.com/users/gziolo/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/gziolo/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'swissspidy',
#       'id': 841956,
#       'node_id': 'MDQ6VXNlcjg0MTk1Ng==',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/841956?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/swissspidy',
#       'html_url': 'https://github.com/swissspidy',
#       'followers_url': 'https://api.github.com/users/swissspidy/followers',
#       'following_url': 'https://api.github.com/users/swissspidy/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/swissspidy/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/swissspidy/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/swissspidy/subscriptions',
#       'organizations_url': 'https://api.github.com/users/swissspidy/orgs',
#       'repos_url': 'https://api.github.com/users/swissspidy/repos',
#       'events_url': 'https://api.github.com/users/swissspidy/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/swissspidy/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'ntwb',
#       'id': 1016458,
#       'node_id': 'MDQ6VXNlcjEwMTY0NTg=',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/1016458?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ntwb',
#       'html_url': 'https://github.com/ntwb',
#       'followers_url': 'https://api.github.com/users/ntwb/followers',
#       'following_url': 'https://api.github.com/users/ntwb/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ntwb/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ntwb/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ntwb/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ntwb/orgs',
#       'repos_url': 'https://api.github.com/users/ntwb/repos',
#       'events_url': 'https://api.github.com/users/ntwb/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ntwb/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'ajitbohra',
#       'id': 1039236,
#       'node_id': 'MDQ6VXNlcjEwMzkyMzY=',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/1039236?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ajitbohra',
#       'html_url': 'https://github.com/ajitbohra',
#       'followers_url': 'https://api.github.com/users/ajitbohra/followers',
#       'following_url': 'https://api.github.com/users/ajitbohra/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ajitbohra/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ajitbohra/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ajitbohra/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ajitbohra/orgs',
#       'repos_url': 'https://api.github.com/users/ajitbohra/repos',
#       'events_url': 'https://api.github.com/users/ajitbohra/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ajitbohra/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'chrisvanpatten',
#       'id': 1231306,
#       'node_id': 'MDQ6VXNlcjEyMzEzMDY=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/1231306?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/chrisvanpatten',
#       'html_url': 'https://github.com/chrisvanpatten',
#       'followers_url': 'https://api.github.com/users/chrisvanpatten/followers',
#       'following_url': 'https://api.github.com/users/chrisvanpatten/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/chrisvanpatten/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/chrisvanpatten/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/chrisvanpatten/subscriptions',
#       'organizations_url': 'https://api.github.com/users/chrisvanpatten/orgs',
#       'repos_url': 'https://api.github.com/users/chrisvanpatten/repos',
#       'events_url': 'https://api.github.com/users/chrisvanpatten/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/chrisvanpatten/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'mmtr',
#       'id': 1233880,
#       'node_id': 'MDQ6VXNlcjEyMzM4ODA=',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/1233880?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mmtr',
#       'html_url': 'https://github.com/mmtr',
#       'followers_url': 'https://api.github.com/users/mmtr/followers',
#       'following_url': 'https://api.github.com/users/mmtr/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mmtr/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mmtr/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mmtr/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mmtr/orgs',
#       'repos_url': 'https://api.github.com/users/mmtr/repos',
#       'events_url': 'https://api.github.com/users/mmtr/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mmtr/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'nerrad',
#       'id': 1429108,
#       'node_id': 'MDQ6VXNlcjE0MjkxMDg=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/1429108?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/nerrad',
#       'html_url': 'https://github.com/nerrad',
#       'followers_url': 'https://api.github.com/users/nerrad/followers',
#       'following_url': 'https://api.github.com/users/nerrad/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/nerrad/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/nerrad/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/nerrad/subscriptions',
#       'organizations_url': 'https://api.github.com/users/nerrad/orgs',
#       'repos_url': 'https://api.github.com/users/nerrad/repos',
#       'events_url': 'https://api.github.com/users/nerrad/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/nerrad/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'aduth',
#       'id': 1779930,
#       'node_id': 'MDQ6VXNlcjE3Nzk5MzA=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/1779930?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/aduth',
#       'html_url': 'https://github.com/aduth',
#       'followers_url': 'https://api.github.com/users/aduth/followers',
#       'following_url': 'https://api.github.com/users/aduth/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/aduth/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/aduth/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/aduth/subscriptions',
#       'organizations_url': 'https://api.github.com/users/aduth/orgs',
#       'repos_url': 'https://api.github.com/users/aduth/repos',
#       'events_url': 'https://api.github.com/users/aduth/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/aduth/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'adamsilverstein',
#       'id': 2676022,
#       'node_id': 'MDQ6VXNlcjI2NzYwMjI=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/2676022?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/adamsilverstein',
#       'html_url': 'https://github.com/adamsilverstein',
#       'followers_url': 'https://api.github.com/users/adamsilverstein/followers',
#       'following_url': 'https://api.github.com/users/adamsilverstein/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/adamsilverstein/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/adamsilverstein/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/adamsilverstein/subscriptions',
#       'organizations_url': 'https://api.github.com/users/adamsilverstein/orgs',
#       'repos_url': 'https://api.github.com/users/adamsilverstein/repos',
#       'events_url': 'https://api.github.com/users/adamsilverstein/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/adamsilverstein/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'etoledom',
#       'id': 9772967,
#       'node_id': 'MDQ6VXNlcjk3NzI5Njc=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/9772967?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/etoledom',
#       'html_url': 'https://github.com/etoledom',
#       'followers_url': 'https://api.github.com/users/etoledom/followers',
#       'following_url': 'https://api.github.com/users/etoledom/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/etoledom/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/etoledom/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/etoledom/subscriptions',
#       'organizations_url': 'https://api.github.com/users/etoledom/orgs',
#       'repos_url': 'https://api.github.com/users/etoledom/repos',
#       'events_url': 'https://api.github.com/users/etoledom/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/etoledom/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'jorgefilipecosta',
#       'id': 11271197,
#       'node_id': 'MDQ6VXNlcjExMjcxMTk3',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/11271197?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jorgefilipecosta',
#       'html_url': 'https://github.com/jorgefilipecosta',
#       'followers_url': 'https://api.github.com/users/jorgefilipecosta/followers',
#       'following_url': 'https://api.github.com/users/jorgefilipecosta/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jorgefilipecosta/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jorgefilipecosta/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jorgefilipecosta/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jorgefilipecosta/orgs',
#       'repos_url': 'https://api.github.com/users/jorgefilipecosta/repos',
#       'events_url': 'https://api.github.com/users/jorgefilipecosta/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jorgefilipecosta/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/WordPress/gutenberg/pulls/19322/commits',
#     'review_comments_url': 'https://api.github.com/repos/WordPress/gutenberg/pulls/19322/comments',
#     'review_comment_url': 'https://api.github.com/repos/WordPress/gutenberg/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/WordPress/gutenberg/issues/19322/comments',
#     'statuses_url': 'https://api.github.com/repos/WordPress/gutenberg/statuses/9812fe60472047b494719d1b8127c319bf8722df',
#     'head': {'label': 'WordPress:try/popover-boundary',
#      'ref': 'try/popover-boundary',
#      'sha': '9812fe60472047b494719d1b8127c319bf8722df',
#      'user': {'login': 'WordPress',
#       'id': 276006,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI3NjAwNg==',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/276006?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/WordPress',
#       'html_url': 'https://github.com/WordPress',
#       'followers_url': 'https://api.github.com/users/WordPress/followers',
#       'following_url': 'https://api.github.com/users/WordPress/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/WordPress/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/WordPress/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/WordPress/subscriptions',
#       'organizations_url': 'https://api.github.com/users/WordPress/orgs',
#       'repos_url': 'https://api.github.com/users/WordPress/repos',
#       'events_url': 'https://api.github.com/users/WordPress/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/WordPress/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 80862584,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk4MDg2MjU4NA==',
#       'name': 'gutenberg',
#       'full_name': 'WordPress/gutenberg',
#       'private': False,
#       'owner': {'login': 'WordPress',
#        'id': 276006,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI3NjAwNg==',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/276006?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/WordPress',
#        'html_url': 'https://github.com/WordPress',
#        'followers_url': 'https://api.github.com/users/WordPress/followers',
#        'following_url': 'https://api.github.com/users/WordPress/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/WordPress/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/WordPress/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/WordPress/subscriptions',
#        'organizations_url': 'https://api.github.com/users/WordPress/orgs',
#        'repos_url': 'https://api.github.com/users/WordPress/repos',
#        'events_url': 'https://api.github.com/users/WordPress/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/WordPress/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/WordPress/gutenberg',
#       'description': 'The Block Editor project for WordPress and beyond. Plugin is available from the official repository.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/WordPress/gutenberg',
#       'forks_url': 'https://api.github.com/repos/WordPress/gutenberg/forks',
#       'keys_url': 'https://api.github.com/repos/WordPress/gutenberg/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/WordPress/gutenberg/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/WordPress/gutenberg/teams',
#       'hooks_url': 'https://api.github.com/repos/WordPress/gutenberg/hooks',
#       'issue_events_url': 'https://api.github.com/repos/WordPress/gutenberg/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/WordPress/gutenberg/events',
#       'assignees_url': 'https://api.github.com/repos/WordPress/gutenberg/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/WordPress/gutenberg/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/WordPress/gutenberg/tags',
#       'blobs_url': 'https://api.github.com/repos/WordPress/gutenberg/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/WordPress/gutenberg/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/WordPress/gutenberg/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/WordPress/gutenberg/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/WordPress/gutenberg/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/WordPress/gutenberg/languages',
#       'stargazers_url': 'https://api.github.com/repos/WordPress/gutenberg/stargazers',
#       'contributors_url': 'https://api.github.com/repos/WordPress/gutenberg/contributors',
#       'subscribers_url': 'https://api.github.com/repos/WordPress/gutenberg/subscribers',
#       'subscription_url': 'https://api.github.com/repos/WordPress/gutenberg/subscription',
#       'commits_url': 'https://api.github.com/repos/WordPress/gutenberg/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/WordPress/gutenberg/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/WordPress/gutenberg/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/WordPress/gutenberg/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/WordPress/gutenberg/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/WordPress/gutenberg/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/WordPress/gutenberg/merges',
#       'archive_url': 'https://api.github.com/repos/WordPress/gutenberg/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/WordPress/gutenberg/downloads',
#       'issues_url': 'https://api.github.com/repos/WordPress/gutenberg/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/WordPress/gutenberg/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/WordPress/gutenberg/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/WordPress/gutenberg/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/WordPress/gutenberg/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/WordPress/gutenberg/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/WordPress/gutenberg/deployments',
#       'created_at': '2017-02-03T19:34:19Z',
#       'updated_at': '2020-01-13T16:13:33Z',
#       'pushed_at': '2020-01-13T16:26:05Z',
#       'git_url': 'git://github.com/WordPress/gutenberg.git',
#       'ssh_url': 'git@github.com:WordPress/gutenberg.git',
#       'clone_url': 'https://github.com/WordPress/gutenberg.git',
#       'svn_url': 'https://github.com/WordPress/gutenberg',
#       'homepage': 'https://wordpress.org/gutenberg/',
#       'size': 325178,
#       'stargazers_count': 5477,
#       'watchers_count': 5477,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 1728,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2385,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 1728,
#       'open_issues': 2385,
#       'watchers': 5477,
#       'default_branch': 'master'}},
#     'base': {'label': 'WordPress:master',
#      'ref': 'master',
#      'sha': '06782e1c3b0c8c4643baa4d0417e0b6e5a5c5214',
#      'user': {'login': 'WordPress',
#       'id': 276006,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI3NjAwNg==',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/276006?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/WordPress',
#       'html_url': 'https://github.com/WordPress',
#       'followers_url': 'https://api.github.com/users/WordPress/followers',
#       'following_url': 'https://api.github.com/users/WordPress/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/WordPress/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/WordPress/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/WordPress/subscriptions',
#       'organizations_url': 'https://api.github.com/users/WordPress/orgs',
#       'repos_url': 'https://api.github.com/users/WordPress/repos',
#       'events_url': 'https://api.github.com/users/WordPress/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/WordPress/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 80862584,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk4MDg2MjU4NA==',
#       'name': 'gutenberg',
#       'full_name': 'WordPress/gutenberg',
#       'private': False,
#       'owner': {'login': 'WordPress',
#        'id': 276006,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI3NjAwNg==',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/276006?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/WordPress',
#        'html_url': 'https://github.com/WordPress',
#        'followers_url': 'https://api.github.com/users/WordPress/followers',
#        'following_url': 'https://api.github.com/users/WordPress/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/WordPress/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/WordPress/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/WordPress/subscriptions',
#        'organizations_url': 'https://api.github.com/users/WordPress/orgs',
#        'repos_url': 'https://api.github.com/users/WordPress/repos',
#        'events_url': 'https://api.github.com/users/WordPress/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/WordPress/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/WordPress/gutenberg',
#       'description': 'The Block Editor project for WordPress and beyond. Plugin is available from the official repository.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/WordPress/gutenberg',
#       'forks_url': 'https://api.github.com/repos/WordPress/gutenberg/forks',
#       'keys_url': 'https://api.github.com/repos/WordPress/gutenberg/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/WordPress/gutenberg/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/WordPress/gutenberg/teams',
#       'hooks_url': 'https://api.github.com/repos/WordPress/gutenberg/hooks',
#       'issue_events_url': 'https://api.github.com/repos/WordPress/gutenberg/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/WordPress/gutenberg/events',
#       'assignees_url': 'https://api.github.com/repos/WordPress/gutenberg/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/WordPress/gutenberg/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/WordPress/gutenberg/tags',
#       'blobs_url': 'https://api.github.com/repos/WordPress/gutenberg/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/WordPress/gutenberg/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/WordPress/gutenberg/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/WordPress/gutenberg/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/WordPress/gutenberg/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/WordPress/gutenberg/languages',
#       'stargazers_url': 'https://api.github.com/repos/WordPress/gutenberg/stargazers',
#       'contributors_url': 'https://api.github.com/repos/WordPress/gutenberg/contributors',
#       'subscribers_url': 'https://api.github.com/repos/WordPress/gutenberg/subscribers',
#       'subscription_url': 'https://api.github.com/repos/WordPress/gutenberg/subscription',
#       'commits_url': 'https://api.github.com/repos/WordPress/gutenberg/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/WordPress/gutenberg/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/WordPress/gutenberg/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/WordPress/gutenberg/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/WordPress/gutenberg/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/WordPress/gutenberg/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/WordPress/gutenberg/merges',
#       'archive_url': 'https://api.github.com/repos/WordPress/gutenberg/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/WordPress/gutenberg/downloads',
#       'issues_url': 'https://api.github.com/repos/WordPress/gutenberg/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/WordPress/gutenberg/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/WordPress/gutenberg/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/WordPress/gutenberg/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/WordPress/gutenberg/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/WordPress/gutenberg/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/WordPress/gutenberg/deployments',
#       'created_at': '2017-02-03T19:34:19Z',
#       'updated_at': '2020-01-13T16:13:33Z',
#       'pushed_at': '2020-01-13T16:26:05Z',
#       'git_url': 'git://github.com/WordPress/gutenberg.git',
#       'ssh_url': 'git@github.com:WordPress/gutenberg.git',
#       'clone_url': 'https://github.com/WordPress/gutenberg.git',
#       'svn_url': 'https://github.com/WordPress/gutenberg',
#       'homepage': 'https://wordpress.org/gutenberg/',
#       'size': 325178,
#       'stargazers_count': 5477,
#       'watchers_count': 5477,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 1728,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2385,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 1728,
#       'open_issues': 2385,
#       'watchers': 5477,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/WordPress/gutenberg/pulls/19322'},
#      'html': {'href': 'https://github.com/WordPress/gutenberg/pull/19322'},
#      'issue': {'href': 'https://api.github.com/repos/WordPress/gutenberg/issues/19322'},
#      'comments': {'href': 'https://api.github.com/repos/WordPress/gutenberg/issues/19322/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/WordPress/gutenberg/pulls/19322/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/WordPress/gutenberg/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/WordPress/gutenberg/pulls/19322/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/WordPress/gutenberg/statuses/9812fe60472047b494719d1b8127c319bf8722df'}},
#     'author_association': 'MEMBER'}},
#   'public': True,
#   'created_at': '2020-01-13T16:28:17Z',
#   'org': {'id': 276006,
#    'login': 'WordPress',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/WordPress',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/276006?'}},
#  {'id': '11263485254',
#   'type': 'PushEvent',
#   'actor': {'id': 3919103,
#    'login': 'hudadiaz',
#    'display_login': 'hudadiaz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hudadiaz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3919103?'},
#   'repo': {'id': 195659837,
#    'name': 'hudadiaz/kamuskita-firebase',
#    'url': 'https://api.github.com/repos/hudadiaz/kamuskita-firebase'},
#   'payload': {'push_id': 4493782890,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c1eca32d460a1f1567d1910783e999ad7da8c28c',
#    'before': '5bb2536b213c1c1d7f3333b9b6b70d1aa354aea3',
#    'commits': [{'sha': 'c1eca32d460a1f1567d1910783e999ad7da8c28c',
#      'author': {'email': 'hudadiaz@gmail.com', 'name': 'Zaid Huda'},
#      'message': 'Update containers to use Hooks',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hudadiaz/kamuskita-firebase/commits/c1eca32d460a1f1567d1910783e999ad7da8c28c'}]},
#   'public': True,
#   'created_at': '2020-01-13T16:28:18Z'},
#  {'id': '11263485238',
#   'type': 'PushEvent',
#   'actor': {'id': 24086,
#    'login': 'markstory',
#    'display_login': 'markstory',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/markstory',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24086?'},
#   'repo': {'id': 873328,
#    'name': 'getsentry/sentry',
#    'url': 'https://api.github.com/repos/getsentry/sentry'},
#   'payload': {'push_id': 4493782867,
#    'size': 17,
#    'distinct_size': 1,
#    'ref': 'refs/heads/ref/project-badge',
#    'head': '8702716d2109f18e5022e335ca91567a6455719b',
#    'before': '5288e5662252ea884010a5d88ffacf4ca6f88909',
#    'commits': [{'sha': 'edf8843ef7e60b1ceb381c8f6f500d88398483ce',
#      'author': {'email': 'mark@sentry.io', 'name': 'Mark Story'},
#      'message': 'ref(discover) Remove the raw field (#16390)\n\nOutputting the raw data when we also output all the formatted keys\r\nwastes space and adds visual noise.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/getsentry/sentry/commits/edf8843ef7e60b1ceb381c8f6f500d88398483ce'},
#     {'sha': '348f90a66302abe41dce161a437be0a9278baac8',
#      'author': {'email': 'mail4alberto@gmail.com', 'name': 'Alberto Leal'},
#      'message': 'fix(discover2): Use transaction root span only if there are no descendent spans for the ops breakdown (#16377)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/getsentry/sentry/commits/348f90a66302abe41dce161a437be0a9278baac8'},
#     {'sha': '94a63d9a3b835cbdf88535d6359367b73f97c169',
#      'author': {'email': 'billyvg@users.noreply.github.com',
#       'name': 'Billy Vong'},
#      'message': 'feat(emotion): Upgrade emotion to v10 (#15106)\n\n* ref(ui): Refactor `cx` from emotion to `classnames`\r\n\r\nWe generally use the `classnames` library to handle merging/dynamic `className`. No reason to use two different libraries.\r\n\r\n* upgrade emotion, add styled wrapper for typings (and related paths), add eslint rules for emotion, update babel plugin\r\n\r\n* Refactor usage of emotion `css` being treated as a class name string\r\n\r\n* change innerRef --> ref\r\n\r\n* refactor grid-emotion props and update to `reflexbox`\r\n\r\n* eslint for emotion-setup\r\n\r\n* refactor injectGlobal --> Global for emotion upgrade\r\n\r\n* Add <CacheProvider>, this is needed to turn speedy off for percy\r\n\r\n* refactor <HeaderItem> - fix missing props to styled components, remove innerRef and forwardRef\r\n\r\n* Change <Tooltip> logic for when to apply a wrapper, emotion causes the previously expected types to be different\r\n\r\n* random TS fixes for styled components\r\n\r\n* fix <RadioGroup> animation needing `css`\r\n\r\n* forwardRef for Switch\r\n\r\n* define a `theme.space` for rebass/grid\r\n\r\n* fix DOM attribute warnings with "loading" prop\r\n\r\n* fix settings breadcrumb - Box in `reflexbox` has different CSS than grid-emotion\r\n\r\n* change <ProviderRow> to remove `Flex` around CircleIndicator as it was squishing it on small widths\r\n\r\n* css fixes for percy\r\n\r\n* fix featureDisabled logic for custom alerts because emotion\r\n\r\n* refactor emotion9 --> emotion10 (imports)\r\n\r\n* update snapshots and fix tests',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/getsentry/sentry/commits/94a63d9a3b835cbdf88535d6359367b73f97c169'},
#     {'sha': '3613ecabbba86c45cf050b0eb7bb709e82c5714c',
#      'author': {'email': 'evanpurkhiser@gmail.com', 'name': 'Evan Purkhiser'},
#      'message': 'feat(drf): Add CamelSnakeSerializer (#16397)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/getsentry/sentry/commits/3613ecabbba86c45cf050b0eb7bb709e82c5714c'},
#     {'sha': 'd49f64d8a678321ba80583ff8aaf88ccd157e76b',
#      'author': {'email': 'aakash@falkon.ai', 'name': 'Aakash Kambuj'},
#      'message': 'docs(workflow): Fix link to screenshots in README.md (#16404)\n\nFixes links to screenshots in README.md broken by 983c8c6',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/getsentry/sentry/commits/d49f64d8a678321ba80583ff8aaf88ccd157e76b'},
#     {'sha': 'c59b4d4ee25335bab8cb2d9aeb386e19e4e02e26',
#      'author': {'email': 'matej.minar@sentry.io', 'name': 'Matej Minar'},
#      'message': 'ref(ts): Convert <QueryCount> to typescript (#16356)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/getsentry/sentry/commits/c59b4d4ee25335bab8cb2d9aeb386e19e4e02e26'},
#     {'sha': '6bef54be9b177cf61698cd6bd5f755f3806ec08b',
#      'author': {'email': 'matej.minar@sentry.io', 'name': 'Matej Minar'},
#      'message': 'ref(ts): Convert <SearchBar> to typescript (#16357)\n\n* ref(ts): Convert <SearchBar> to typescript\r\n\r\n* removed proptypes, placeholder optional',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/getsentry/sentry/commits/6bef54be9b177cf61698cd6bd5f755f3806ec08b'},
#     {'sha': 'be4e290278c51971e5317bd3173be3fb41981794',
#      'author': {'email': 'matej.minar@sentry.io', 'name': 'Matej Minar'},
#      'message': 'ref(ts): Convert getOnboardingTasks to typescript (#16348)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/getsentry/sentry/commits/be4e290278c51971e5317bd3173be3fb41981794'},
#     {'sha': '7d7206745c4f6f600a677c7266ae5a6afff4ba45',
#      'author': {'email': 'matej.minar@sentry.io', 'name': 'Matej Minar'},
# ...
#       'comments_url': 'https://api.github.com/repos/macuser413/checkpoint-react-seir/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/macuser413/checkpoint-react-seir/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/macuser413/checkpoint-react-seir/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/macuser413/checkpoint-react-seir/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/macuser413/checkpoint-react-seir/merges',
#       'archive_url': 'https://api.github.com/repos/macuser413/checkpoint-react-seir/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/macuser413/checkpoint-react-seir/downloads',
#       'issues_url': 'https://api.github.com/repos/macuser413/checkpoint-react-seir/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/macuser413/checkpoint-react-seir/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/macuser413/checkpoint-react-seir/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/macuser413/checkpoint-react-seir/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/macuser413/checkpoint-react-seir/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/macuser413/checkpoint-react-seir/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/macuser413/checkpoint-react-seir/deployments',
#       'created_at': '2020-01-13T15:02:26Z',
#       'updated_at': '2020-01-13T16:03:30Z',
#       'pushed_at': '2020-01-13T16:03:27Z',
#       'git_url': 'git://github.com/macuser413/checkpoint-react-seir.git',
#       'ssh_url': 'git@github.com:macuser413/checkpoint-react-seir.git',
#       'clone_url': 'https://github.com/macuser413/checkpoint-react-seir.git',
#       'svn_url': 'https://github.com/macuser413/checkpoint-react-seir',
#       'homepage': None,
#       'size': 0,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'ga-wdi-exercises:master',
#      'ref': 'master',
#      'sha': '3779a30f8dfcde8640d47b910cae8fe0b7b1625e',
#      'user': {'login': 'ga-wdi-exercises',
#       'id': 16946328,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE2OTQ2MzI4',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/16946328?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ga-wdi-exercises',
#       'html_url': 'https://github.com/ga-wdi-exercises',
#       'followers_url': 'https://api.github.com/users/ga-wdi-exercises/followers',
#       'following_url': 'https://api.github.com/users/ga-wdi-exercises/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ga-wdi-exercises/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ga-wdi-exercises/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ga-wdi-exercises/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ga-wdi-exercises/orgs',
#       'repos_url': 'https://api.github.com/users/ga-wdi-exercises/repos',
#       'events_url': 'https://api.github.com/users/ga-wdi-exercises/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ga-wdi-exercises/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 233619663,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMzM2MTk2NjM=',
#       'name': 'checkpoint-react-seir',
#       'full_name': 'ga-wdi-exercises/checkpoint-react-seir',
#       'private': False,
#       'owner': {'login': 'ga-wdi-exercises',
#        'id': 16946328,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE2OTQ2MzI4',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/16946328?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ga-wdi-exercises',
#        'html_url': 'https://github.com/ga-wdi-exercises',
#        'followers_url': 'https://api.github.com/users/ga-wdi-exercises/followers',
#        'following_url': 'https://api.github.com/users/ga-wdi-exercises/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ga-wdi-exercises/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ga-wdi-exercises/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ga-wdi-exercises/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ga-wdi-exercises/orgs',
#        'repos_url': 'https://api.github.com/users/ga-wdi-exercises/repos',
#        'events_url': 'https://api.github.com/users/ga-wdi-exercises/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ga-wdi-exercises/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/ga-wdi-exercises/checkpoint-react-seir',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir',
#       'forks_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/forks',
#       'keys_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/teams',
#       'hooks_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/events',
#       'assignees_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/tags',
#       'blobs_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/languages',
#       'stargazers_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/subscription',
#       'commits_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/merges',
#       'archive_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/downloads',
#       'issues_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/deployments',
#       'created_at': '2020-01-13T14:51:37Z',
#       'updated_at': '2020-01-13T15:06:41Z',
#       'pushed_at': '2020-01-13T16:18:00Z',
#       'git_url': 'git://github.com/ga-wdi-exercises/checkpoint-react-seir.git',
#       'ssh_url': 'git@github.com:ga-wdi-exercises/checkpoint-react-seir.git',
#       'clone_url': 'https://github.com/ga-wdi-exercises/checkpoint-react-seir.git',
#       'svn_url': 'https://github.com/ga-wdi-exercises/checkpoint-react-seir',
#       'homepage': None,
#       'size': 275,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 27,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 21,
#       'license': None,
#       'forks': 27,
#       'open_issues': 21,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/pulls/11'},
#      'html': {'href': 'https://github.com/ga-wdi-exercises/checkpoint-react-seir/pull/11'},
#      'issue': {'href': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/issues/11'},
#      'comments': {'href': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/issues/11/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/pulls/11/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/pulls/11/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/ga-wdi-exercises/checkpoint-react-seir/statuses/f43eb7192df3ca6f84bc564111b913f181e76452'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'unstable',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1438,
#     'deletions': 1306,
#     'changed_files': 9}},
#   'public': True,
#   'created_at': '2020-01-13T16:28:17Z',
#   'org': {'id': 16946328,
#    'login': 'ga-wdi-exercises',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ga-wdi-exercises',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16946328?'}},
#  {'id': '11263485091',
#   'type': 'PushEvent',
#   'actor': {'id': 56094469,
#    'login': 'eanaya-leantech',
#    'display_login': 'eanaya-leantech',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eanaya-leantech',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56094469?'},
#   'repo': {'id': 223645205,
#    'name': 'Lean-Tech/create-react-lean-tech',
#    'url': 'https://api.github.com/repos/Lean-Tech/create-react-lean-tech'},
#   'payload': {'push_id': 4493782806,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/feature-demo2',
#    'head': 'c0ceca979110831b64f6a5784193da396adb13b4',
#    'before': '7eaf907458a2847b5b7918317cfffa240c79b326',
#    'commits': [{'sha': 'c0ceca979110831b64f6a5784193da396adb13b4',
#      'author': {'email': 'eanaya@lean-tech.io', 'name': 'Edwin Anaya'},
#      'message': 'Update README.md\n\ndemo',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Lean-Tech/create-react-lean-tech/commits/c0ceca979110831b64f6a5784193da396adb13b4'}]},
#   'public': True,
#   'created_at': '2020-01-13T16:28:17Z',
#   'org': {'id': 58117460,
#    'login': 'Lean-Tech',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lean-Tech',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58117460?'}},
#  {'id': '11263485075',
#   'type': 'PushEvent',
#   'actor': {'id': 1812179,
#    'login': 'cliffordp',
#    'display_login': 'cliffordp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cliffordp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1812179?'},
#   'repo': {'id': 40343752,
#    'name': 'moderntribe/event-tickets',
#    'url': 'https://api.github.com/repos/moderntribe/event-tickets'},
#   'payload': {'push_id': 4493782791,
#    'size': 6,
#    'distinct_size': 1,
#    'ref': 'refs/heads/fix/ETP-50-page-template',
#    'head': '355b3edbb51ec1f6d879a47075c427f97a8db93d',
#    'before': '5cdd2cb5dd955f71083ce5ad83de8025e89e55e9',
#    'commits': [{'sha': 'ae889d9eb44fd76d3c01dc05d24eafd6ce72f662',
#      'author': {'email': 'tko@tourkick.com', 'name': 'Clifford Paulick'},
#      'message': 'Add `>` to opening div to fix the issue',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/moderntribe/event-tickets/commits/ae889d9eb44fd76d3c01dc05d24eafd6ce72f662'},
#     {'sha': '4d264006e595f49d5b70bdb2e8104fc4416e29d8',
#      'author': {'email': 'tko@tourkick.com', 'name': 'Clifford Paulick'},
#      'message': 'array() to []',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/moderntribe/event-tickets/commits/4d264006e595f49d5b70bdb2e8104fc4416e29d8'},
#     {'sha': '2047d3bc6c737cb7a204aef0a33a82af57803582',
#      'author': {'email': 'tko@tourkick.com', 'name': 'Clifford Paulick'},
#      'message': 'better wording',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/moderntribe/event-tickets/commits/2047d3bc6c737cb7a204aef0a33a82af57803582'},
#     {'sha': 'd2e90a0c61b2e9862416308d50cdbc97e172bda1',
#      'author': {'email': 'lol@scottkclark.com',
#       'name': 'Scott Kingsley Clark'},
#      'message': "Merge branch 'release/G20.01' into fix/ET-589-close-div-tag",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/moderntribe/event-tickets/commits/d2e90a0c61b2e9862416308d50cdbc97e172bda1'},
#     {'sha': '5d05af28074ce03467987056918b291caef3d53b',
#      'author': {'email': 'tko@tourkick.com', 'name': 'Clifford'},
#      'message': 'Merge pull request #1535 from moderntribe/fix/ET-589-close-div-tag\n\nET-589 close open div',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/moderntribe/event-tickets/commits/5d05af28074ce03467987056918b291caef3d53b'},
#     {'sha': '355b3edbb51ec1f6d879a47075c427f97a8db93d',
#      'author': {'email': 'tko@tourkick.com', 'name': 'Clifford'},
#      'message': "Merge branch 'release/G20.01' into fix/ETP-50-page-template",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/moderntribe/event-tickets/commits/355b3edbb51ec1f6d879a47075c427f97a8db93d'}]},
#   'public': True,
#   'created_at': '2020-01-13T16:28:17Z',
#   'org': {'id': 2279551,
#    'login': 'moderntribe',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/moderntribe',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2279551?'}}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0'},
#  'origin': '114.36.129.125, 114.36.129.125',
#  'url': 'https://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'json': None,
#  'origin': '123.195.194.127, 123.195.194.127',
#  'url': 'https://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
